# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Standard library
import gc
import logging
from pathlib import Path

import shap
import xgboost as xgb
from Experiment import Experiment
from Dataset import Dataset
from newutils.other.helpers import init_context

init_context()

# %%
logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(name)s - %(levelname)s - %(message)s"
)

# %%
outpath = Path("/root/2025-Project-188/artifacts") / "random_forest_1000" / "models"
outpath.mkdir(parents=True, exist_ok=True)
experiment = Experiment(outpath)

# %%
experiment.model_paths
# Out:
# []

# %%
params = {
    "tree_method": "hist",
    "learning_rate": 1,
    "max_depth": 14,
    "colsample_bynode": 0.7,
    "subsample": 0.7,
    "seed": [14, 18, 30, 42, 146, 436][0],
    "colsample_bytree": 1,
    # "objective": "reg:squarederror",
    "eval_metric": "mape",
    # "eval_metric": "rmse",
    "num_boost_round": 1,
    "verbose_eval": 1,
    "n_jobs": -1,
    "num_load": None,
    "partition_size": "100MB",
    "num_parallel_tree": 50,
}
experiment.make(params)
# Out:
# 2025-05-22 14:23:44,565 - Experiment - INFO - Prepare experiment.
# 2025-05-22 14:23:44,569 - Experiment - INFO - Performing train/test split on X and y.
# 2025-05-22 14:23:45,713 - Experiment - WARNING - DEBUG: Use only one feature to predict.
# 2025-05-22 14:23:45,729 - Experiment - INFO - Creating XGBoost DMatrix.
# 2025-05-22 14:23:46,824 - Experiment - INFO - Creating XGBoost DMatrix.
# 2025-05-22 14:23:47,213 - Experiment - INFO - Start model training.
# /root/.cache/pypoetry/virtualenvs/pro-1-experiments-3s_W9-_F-py3.11/lib/python3.11/site-packages/xgboost/training.py:38: UserWarning: `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
#   warnings.warn(
# ...
